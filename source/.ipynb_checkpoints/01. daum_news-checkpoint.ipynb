# %% [markdown]
# ## Daum news web crawling
#
# - 데이터수집 기간 : 뉴스 게시일 기준 최근 6개월
# - 키워드 : ['노인', '어르신', '시니어', '고령자', '노년층']

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re
from tqdm import tqdm

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3)

# %%
title_list = []
date_company_list = []
content_list = []

keywords = ['노인', '어르신', '시니어', '고령자', '노년층']

for keyword in keywords:
    # 리스트 초기화
    title_list = []
    date_company_list = []
    content_list = []
        
    # Daum 접속
    url = 'https://news.daum.net/'
    driver.get(url)
    time.sleep(2)

    # 검색 버튼 클릭
    search_selector = '#qVal'
    src = driver.find_element_by_css_selector(search_selector)
    src.click()

    # 검색 키워드 입력
    elem = driver.find_element_by_css_selector(search_selector)
    elem.send_keys(keyword)
    elem.send_keys(Keys.ENTER)
    time.sleep(2)

    # 검색 키워드 삭제
    # elem = driver.find_element_by_css_selector(search_selector)
    # elem.clear()

    # '뉴스 더보기' 클릭
    more_view_selector = '#newsExtMore > span'
    src = driver.find_element_by_css_selector(more_view_selector)
    src.click()
    time.sleep(2)

    # '기간' 클릭
    duration_selector = '#newsColl > div.coll_tabopt > div:nth-child(1) > a > span.txt_data'
    src = driver.find_element_by_css_selector(duration_selector)
    src.click()
    time.sleep(2)

    # 기간 6개월 클릭
    six_month_selector = '#newsColl > div.coll_tabopt > div.menu_opt.opt_open > div > ul > li:nth-child(5) > a > span'
    src = driver.find_element_by_css_selector(six_month_selector)
    src.click()
    time.sleep(2)

    # 데이터 수집 + 페이지 이동
    while True:    
        # 제목 수집
        title_selector = 'li > div.wrap_cont > div > div > a'
        titles = driver.find_elements_by_css_selector(title_selector)
        for i in titles:
            title_list.append(i.text)

        # 게시일/언론사 수집
        date_company_selector = '#clusterResultUL > li > div.wrap_cont > div > span.f_nb.date'
        dates_companies = driver.find_elements_by_css_selector(date_company_selector)
        for i in dates_companies:
            date_company_list.append(i.text)
        
        # 내용(요약) 수집
        content_selector = '#clusterResultUL > li > div.wrap_cont > div > p'
        contents = driver.find_elements_by_css_selector(content_selector)
        for i in contents:
            content_list.append(i.text)
        
        # 페이지 다음 버튼
        next_page_selector = '#newsColl > div.paging_comm > span > span:nth-child(3) > a'
        next_page = driver.find_element_by_css_selector(next_page_selector)
        next_page.click()
        time.sleep(2)
        
        # 페이지가 더이상 없을 경우 반복 중단
        next_page_selector = '#newsColl > div.paging_comm > span > span:nth-child(3) > a'
        next_page = driver.find_elements_by_css_selector(next_page_selector)
        if len(next_page) == 0:
            break
        
    print(keyword, ': 수집완료', len(title_list), len(date_company_list), len(content_list))
    
    # 저장 (csv)
    df = pd.DataFrame({'title':title_list,'date_company':date_company_list,'content':content_list})
    df.to_csv('daum_news_title_'+keyword+'.csv', index = None)
# Out:
# 노인 : 수집완료 790 790 790
# 어르신 : 수집완료 790 790 790
# 시니어 : 수집완료 790 790 790
# 고령자 : 수집완료 790 790 790
# 노년층 : 수집완료 790 790 790

# %% [markdown]
# **[결론]**
# - 위와 같은 코드로 수행할 경우 80번째 페이지에서 다음 페이지로 넘어가는 버튼이 비활성화 되기 때문에 최대 80페이지 까지만 데이터 수집이 가능하다.
# - tqdm 라이브러리를 알게된 이후로 사용하고 싶은데, 무한루프에서는 사용이 제한된다는 것이 아쉬웠다. 80페이지 부터 다음 페이지로 넘어가는 버튼이 비활성화 되는 이슈 때문에 내가 알고 있는 로직으로 ('다음' 페이지 버튼의 elements 에 대해서 찾고 1 또는 0 을 반환하여 조건문을 통해 break 하는 방법) 수행할 수 밖에 없었다.
# - 지금 까지 해본 크롤링 코드중에서 가장 깔끔하게 구현은 한것 같아서 만족은 하지만, 비활성화에 대한 이슈로 더 많은 자료를 수집할 수 없는 부분에 대해서는 아쉬움으로 남는다.

# %% [markdown]
# ## Preprocessing
# - 모든 키워드의 title과 content 컬럼 병합

# %%
# 파일 불러오기
data = pd.read_csv('../data/daum_news_title_독거노인_ver1.csv')
data.drop_duplicates() # 중복행 제거
# Out:
#                                      title               date_company  \
# 0                 NH농협은행, 독거노인지원센터에 후원금 전달        1시간전 | 스포츠조선 | 다음뉴스
# 1       최근 5년간 독거노인 30%↑..무연고 노인 고독사 2배 급증  2021.05.08 | 헤럴드경제 | 다음뉴스
# 2        레페리, 어버이날 맞아 지역 독거 노인에게 4억원 물품 기부       14시간전 | 아시아경제 | 다음뉴스
# 3          당진의용소방대 연합회, 독거노인 위해 마스크 1만개 기부                16분전 | 대전일보
# 4                합천군자원봉사협의회 독거노인 생신 도시락 전달                3시간전 | 시민일보
# ..                                     ...                        ...
# 795    수원시 호매실동, 독거노인 안전지킴이 '가스타이머콕 설치' 지원          2021.04.12 | 뉴스피크
# 796  [오산시] 독거노인의 정서지원을 위한 민․관협력「마음돌봄, 함...       2021.04.15 | OBC더원방송
# 797           안산 상록수보건소, 독거어르신 가슴에 카네이션 선물         2021.05.07 | 경기앤뉴스
# 798    광주 남구, '팽현숙.최양락 부부' 독거노인 위해 "착한 후원"          2021.04.16 | NGTV
# 799           안산 상록수보건소, 독거어르신 가슴에 카네이션 선물          2021.05.07 | 경인신문
#
#                                                content        date  company
# 0    7일 JW메리어트 동대문 스퀘어 서울에서 개최된 '어버이날 孝사랑 큰잔치'에서 독거...        1시간전    스포츠조선
# 1    우리나라 노인 인구 추이’를 분석한 결과에 따르면 2016년 127만5316명이던 ...  2021.05.08    헤럴드경제
# 2    경제 김보경 기자] 뷰티 인플루언서 비즈니스 그룹 레페리는 어버이날을 맞아 독거 노...       14시간전    아시아경제
# 3    여성회장 이영례)는 코로나19 확산세가 거센 가운데, 지역 내 경제적으로 어려운 독...        16분전     대전일보
# 4    5월중에 미역국 도시락을 전달할 예정이며, 12월까지 읍면 자원봉사협의회에서 독거노...        3시간전     시민일보
# ..                                                 ...         ...      ...
# 795  로타리클럽(회장 최정진)과 지역사회보장협의체(위원장 심윤식)는 뜻을 모아 저소득 독...  2021.04.12     뉴스피크
# 796  관장, 실무자 등과 6개동 지역사회보장협의체 위원장 및 동장 등이 참석한 가운데 독...  2021.04.15  OBC더원방송
# 797  [경기&뉴스] 안산시 상록수보건소는 어버이날을 맞아 관내 독거노인 70명을 대상으로...  2021.05.07    경기앤뉴스
# 798  연예계 잉꼬 부부인 팽현숙‧최양락씨가 광주 남구 관내 독거노인의 끼니 걱정을 덜어주...  2021.04.16     NGTV
# 799  [경인신문] 안산시 상록수보건소는 어버이날을 맞아 관내 독거노인 70명을 대상으로 ...  2021.05.07     경인신문
#
# [709 rows x 5 columns]

# %% [markdown]
# ## Preprocessing1
#
# - date와 company 분리

# %%
keywords = ['노인', '어르신', '시니어', '고령자', '노년층']
date = []
company = []

for keyword in keywords:
    
    # 다음 키워드로 이동할 때 리스트 초기화
    date = []
    company = []
    
    # 저장된 파일 불러오기
    df = pd.read_csv('daum_news_title_'+keyword+'.csv')

    # split 함수를 이용하여 date와 company 쪼개고 새로운 컬럼으로 추가
    date_company = df.date_company
    date_company
    for i in date_company:
        date_split = i.split(' | ')[0]
        date.append(date_split)   
    df['date'] = date

    for i in date_company:
        company_split = i.split(' | ')[1]
        company.append(company_split)   
    df['company'] = company
    df.head()

    # 저장 (csv)
    df.to_csv('daum_news_title_'+keyword+'_ver1.csv', index = None)

# %% [markdown]
# ## Preprocessing2
# - title과 content 형태소 분석기 사용하여 단어 빈출도 추출

# %%
import pandas as pd
import re

# %%
# 파일 불러오기
    
data1 = pd.read_csv('daum_news_title_고령자.csv')
data2 = pd.read_csv('daum_news_title_노년층.csv')
data3 = pd.read_csv('daum_news_title_노인.csv')
data4 = pd.read_csv('daum_news_title_시니어.csv')
data5 = pd.read_csv('daum_news_title_어르신.csv')

# %%
data = pd.concat([data1, data2, data3, data4, data5])
data_all = pd.concat([data.title, data.content])
data_all
# Out:
# 0                                   양평군, 고령자복지주택 공모사업 선정
# 1                          양평 공흥지구, 고령자복지주택 선정..100세대 공급
# 2                      주택·사회복지시설 복합…양평군 '고령자복지 임대주택' 짓는다
# 3                 전기차 충전소 확대·고령자 디지털 접근성 개선..행안부, 우수사...
# 4                  [과학] "팬데믹 후 고령자 힐링 관광..청정·안전 담아 승부하라"
#                              ...
# 785    1) = 서울의료원이 어버이날을 하루 앞둔 7일 코로나19로 인해 가족들의 면회가 ...
# 786    통신 최병찬 기자] 부천시는 ㈜비엔비아이엔티가 5월 가정의 달을 맞이하여, 독거 어...
# 787    여성회는 어버이날을 맞아 6일 11시 `요셉의 집 무료급식 봉사활동`을 실시하며 어...
# 788    뉴스신문) 주기범 기자 | 부천시는 ㈜비엔비아이엔티가 5월 가정의 달을 맞이하여, ...
# 789    안양시, 경로식당 9개소 어르신에게 특별식과 선물로 훈훈 [미디어투데이=안정태 기자...
# Length: 7900, dtype: object

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
# title data 합치기 (제거: '\n')
message = ''
for item in data_all:
    message = message + re.sub('[^\w]', ' ', item) +''

# 정규화 (제거할 단어)
message = re.sub('노인', '', message)
message = re.sub('어르신', '', message)
message = re.sub('시니어', '', message)
message = re.sub('고령자', '', message)
message = re.sub('노년층', '', message)

# message

# %%
# 명사 추출
nlp = Okt()
message_N = nlp.nouns(message)
# message_N

# %%
# 단어 빈도 확인
count = Counter(message_N)
word_count = dict()

for tag, counts in count.most_common(200):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print(tag,':',counts)
# Out:
# 기자 : 1020
# 접종 : 974
# 이상 : 930
# 사업 : 843
# 어버이날 : 826
# 전달 : 819
# 백신 : 801
# 코로나 : 795
# 센터 : 701
# 지난 : 647
# 지역 : 633
# 건강 : 585
# 복지관 : 565
# 독거 : 539
# 대상 : 493
# 서비스 : 486
# 복지 : 483
# 지원 : 463
# 가정 : 443
# 사회 : 433
# 위해 : 425
# 일자리 : 415
# 행사 : 381
# 카네이션 : 377
# 뉴스 : 363
# 운영 : 358
# 모델 : 352
# 주택 : 333
# 서울 : 325
# 클럽 : 311
# 이번 : 301
# 협의 : 295
# 소득 : 291
# 취약 : 282
# 인천 : 280
# 사랑 : 279
# 시작 : 275
# 장애인 : 274
# 진행 : 256
# 맞춤 : 255
# 계층 : 255
# 가구 : 251
# 시설 : 248
# 디지털 : 244
# 종합 : 241
# 실시 : 236
# 선물 : 236
# 제공 : 234
# 홀몸 : 233
# 나눔 : 232
# 교보 : 226
# 출시 : 225
# 협약 : 224
# 방문 : 218
# 맞이 : 216
# 대한 : 213
# 안전 : 211
# 예방접종 : 210
# 세대 : 206
# 예방 : 206
# 개최 : 205
# 트롯 : 205
# 보험 : 203
# 사회보장 : 200
# 가입 : 195
# 프로그램 : 192
# 교육 : 190
# 사진 : 188
# 한국 : 187
# 활용 : 187
# 활동 : 184
# 청년 : 183
# 시흥 : 183
# 개발 : 181
# 업무 : 181
# 통해 : 181
# 추진 : 180
# 관내 : 176
# 연구 : 175
# 증강현실 : 170
# 고객 : 169
# 치매 : 168
# 선정 : 161
# 생명 : 159
# 공동 : 156
# 화이자 : 155
# 사용 : 155
# 관장 : 154
# 농협 : 153
# 꾸러미 : 152
# 간편 : 151
# 후원 : 151
# 기술 : 150
# 고령 : 148
# 관리 : 147
# 병력 : 147
# 문화 : 146
# 참여 : 145
# 감사 : 143
# 마을 : 142
# 시장 : 137
# 콘텐츠 : 134
# 대회 : 133
# 신문 : 132
# 최근 : 131
# 마음 : 129
# 체결 : 129
# 대표 : 129
# 관련 : 128
# 장수 : 127
# 경기 : 126
# 창업 : 126
# 경기도 : 124
# 생활 : 123
# 준비 : 121
# 예약 : 118
# 은행 : 117
# 시흥시 : 116
# 주민 : 115
# 재단 : 115
# 홀로 : 115
# 기반 : 114
# 촬영 : 114
# 스마트 : 113
# 거주 : 113
# 기념 : 113
# 봉사 : 109
# 단백질 : 108
# 인력 : 106
# 통합 : 106
# 가족 : 106
# 청장 : 106
# 질환 : 105
# 안심 : 105
# 정부 : 105
# 소외 : 104
# 상담 : 104
# 모집 : 103
# 확대 : 101
# 착수 : 101
# 회장 : 101
# 마련 : 101
# 현장 : 100
# 설치 : 99
# 병원 : 99
# 완화 : 98
# 전국체전 : 98
# 아시아 : 98
# 물품 : 97
# 개선 : 96
# 오늘 : 96
# 행복 : 96
# 기초 : 96
# 상품 : 95
# 교통 : 94
# 신청 : 94
# 프로젝트 : 94
# 경제 : 93
# 스마트폰 : 93
# 완료 : 92
# 임대 : 92
# 기관 : 92

# %% [markdown]
# ## Visualization (히스토그램)

# %%
import matplotlib.pyplot as plt

font_path = "../data/THEdog.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.figure(figsize=(28,6))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='70')

plt.show()

# %% [markdown]
# ## Visualization (워드클라우드)

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path, background_color='white', width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(15,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# 워드클라우드 png저장
wc.to_file('daum_news_wordcloud.png')

# 워드 클라우드 색 찾아보기: scale_color_gradient(low = "#66aaf2", high = "#004EA1") +
