# %% [markdown]
# # 모듈 모음

# %%
# !pip install konlpy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import pandas as pd
import numpy as np
import re
from konlpy.tag import Okt
from sklearn.metrics.pairwise import euclidean_distances # ==> 유클리디언 유사도
from sklearn.metrics.pairwise import manhattan_distances # ==> 맨하탄 유사도

# %% [markdown]
# # Mecab 형태소 분석기 Goggle Colab 설치

# %%
! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab/

# %%
! bash install_mecab-ko_on_colab190912.sh

# %%
from konlpy.tag import Mecab

# %% [markdown]
# # 데이터 로드

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TF-IDF_Test/Total_chat_data.csv')
df
# Out:
#                                                question                                   answer
# 0                                               ﻿좋은 아침.                                   안녕하세요.
# 1                                                좋은 아침.                                   반갑습니다.
# 2                                                좋은 아침.                                좋은 아침이에요.
# 3                                                좋은 아침.                             간밤에 별일 없으셨죠?
# 4                                                좋은 아침.                                  안녕하십니까?
# ...                                                 ...                                      ...
# 2393  그 사람이 응급실 의사한테 뭐라고 속닥거리니까, 저보고 갑자기 응급처치 끝났다고, ...            응급실이 있어서 다행이네요. 큰 문제는 없으신 거죠?
# 2394                   파편이 튀어서 그 때 저도 응급실 가서 치료 받기도 했고…  응급실에 가셨다니 정말 놀랐어요. 아무 문제 없으신가요? 걱정 되네요.
# 2395                     지금 상태가 너무 안 좋아서 학교 안 나가고 있어요.                  상태가 더 안 좋아지셨군요. 걱정이 되네요.
# 2396                                   진짜 심해진 거 같긴 해요.                 정말 힘드시겠어요. 지금도 증상이 심하신가요?
# 2397                                 그런데 증상이 나빠진 거 같아.                너무 심하시면 병원을 다시 가보는 건 어떨까요?
#
# [2398 rows x 2 columns]

# %% [markdown]
# # 데이터 전처리

# %%
# 한글, 숫자, 영어 빼고 전부 제거

def text_preprocessing(text):
    return re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣0-9a-zA-Z]', '', text)

q_prepro = df.question.map(text_preprocessing)
a_prepro = df.answer.map(text_preprocessing)
new_df = pd.concat([q_prepro, a_prepro], axis=1)
new_df
# Out:
#                                          question                        answer
# 0                                            좋은아침                         안녕하세요
# 1                                            좋은아침                         반갑습니다
# 2                                            좋은아침                       좋은아침이에요
# 3                                            좋은아침                     간밤에별일없으셨죠
# 4                                            좋은아침                        안녕하십니까
# ...                                           ...                           ...
# 2393  그사람이응급실의사한테뭐라고속닥거리니까저보고갑자기응급처치끝났다고나가라고하더라구요         응급실이있어서다행이네요큰문제는없으신거죠
# 2394                       파편이튀어서그때저도응급실가서치료받기도했고  응급실에가셨다니정말놀랐어요아무문제없으신가요걱정되네요
# 2395                         지금상태가너무안좋아서학교안나가고있어요             상태가더안좋아지셨군요걱정이되네요
# 2396                                   진짜심해진거같긴해요           정말힘드시겠어요지금도증상이심하신가요
# 2397                                 그런데증상이나빠진거같아           너무심하시면병원을다시가보는건어떨까요
#
# [2398 rows x 2 columns]

# %% [markdown]
# # Okt 형태소 분석기 사용

# %%
okt = Okt()

# 임의 불용어 사전
STOP_WORDS = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다', '정도', '크' ]

def okt_tokenize(text):
    token_all = []

    # 형태소 분석
    tmp = okt.morphs(text, stem=True)

    # 불용어 처리
    for token in tmp :
        if token not in STOP_WORDS:
            token_all.append(token)
    
    result = ' '.join(token_all)

    return result

q_seriese = new_df.question.map(okt_tokenize)
a_seriese = new_df.answer.map(okt_tokenize)

ok_df = pd.DataFrame([q_seriese, a_seriese])

ok_df = ok_df.T
ok_df
# Out:
#                                             question                           answer
# 0                                              좋다 아침                             안녕하다
# 1                                              좋다 아침                              반갑다
# 2                                              좋다 아침                        좋다 아침 이에요
# 3                                              좋다 아침                         간밤 별일 없다
# 4                                              좋다 아침                           안녕하십니까
# ...                                              ...                              ...
# 2393  그 사람 응급실 의사 한테 뭐라다 속닥거리다 저 보고 갑자기 응급처치 끝나다 나가다      응급실 있다 다행 이네 요 크다 문제 없다 거 죠
# 2394                  파편 튀어 서 그때 저 도응 급 실가 서 치료받다 기도  응급실 가다 정말 놀라다 아무 문제 없다 가요 걱정 되다
# 2395                           지금 상태 너무 안좋다 학교 안나 가다                 상태 가다 좋아지다 걱정 되다
# 2396                                    진짜 심해지다 같다 요                 정말 힘들다 지금 증상 심하다
# 2397                                그런데 증상 이나 빠지다 같다         너 무심하다 병원 을 다시 가보다 어떻다 요
#
# [2398 rows x 2 columns]

# %% [markdown]
# # Mecab 형태소 분석기

# %%
# Mecab 불용어 사전

f = open('/content/drive/MyDrive/Colab Notebooks/TF-IDF_Test/koreanStopwords.txt', 'r')
lines = f.readlines()
stopwords = []
for line in lines:
    line = line.replace('\n', '')
    stopwords.append(line)
f.close()

print(stopwords)
# Out:
# ['이', '있', '하', '것', '들', '그', '되', '수', '이', '보', '않', '없', '나', '사람', '주', '아니', '등', '같', '우리', '때', '년', '가', '한', '지', '대하', '오', '말', '일', '그렇', '위하', '때문', '그것', '두', '말하', '알', '그러나', '받', '못하', '일', '그런', '또', '문제', '더', '사회', '많', '그리고', '좋', '크', '따르', '중', '나오', '가지', '씨', '시키', '만들', '지금', '생각하', '그러', '속', '하나', '집', '살', '모르', '적', '월', '데', '자신', '안', '어떤\t', '내', '경우', '명', '생각', '시간', '그녀', '다시', '이런', '앞', '보이', '번', '나', '다른', '어떻', '여자', '개\t', '들', '사실', '이렇', '점', '싶', '말', '정도', '좀', '원', '잘', '통하', '소리', '놓\t']

# %%
# Mecab 형태소 분석기

mecab = Mecab()

def mecab_tokenize(text):
    token_all = []

    # 형태소 분석
    tmp = mecab.morphs(text)

    # 불용어 처리
    for token in tmp :
        if token not in stopwords:
            token_all.append(token)
    
    result = ' '.join(token_all)

    return result

q_seriese = new_df.question.map(mecab_tokenize)
a_seriese = new_df.answer.map(mecab_tokenize)

me_df = pd.DataFrame([q_seriese, a_seriese])

me_df = me_df.T
me_df
# Out:
#                                                question                              answer
# 0                                                  은 아침                               안녕 세요
# 1                                                  은 아침                              반갑 습니다
# 2                                                  은 아침                             은 아침 에요
# 3                                                  은 아침                        간밤 에 별일 으셨 죠
# 4                                                  은 아침                              안녕 십니까
# ...                                                 ...                                 ...
# 2393  응급실 의사 한테 뭐 라고 속닥거리 니까 저 보고 갑자기 응급처치 끝 났 다고 나가...             응급실 어서 다행 네요 큰 는 으신 거 죠
# 2394                    파편 튀 어서 그때 저 도 응급실 서 치료 기 도 했 고  응급실 에 셨 다니 정말 놀랐 어요 아무 으신 가요 걱정 네요
# 2395                                상태 너무 아서 학교 나가 고 어요                     상태 아 셨 군요 걱정 네요
# 2396                                      진짜 심해진 거 긴 해요            정말 힘드 시 겠 어요 도 증상 심하 신가요
# 2397                                   그런데 증상 이나 빠진 거 아            너무 심하 시 면 병원 을 는 건 어떨까 요
#
# [2398 rows x 2 columns]

# %% [markdown]
# # 코사인 유사도 함수

# %%
# 코사인 유사도로 정답 구하는 함수

def cos_answer(new_q, new_df):
    tfidf = TfidfVectorizer()
    new_q = pd.Series(new_q)
    all_q = new_df.question.append(new_q)
    tfidf_matrix = tfidf.fit_transform(all_q)
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    questions = cosine_sim[-1][:-1]
    if 1. in questions:
        indices = np.where(questions == 1.)
        indices = indices[0].tolist()
        q_idx = np.random.choice(indices, 1)
        return df.answer[q_idx[0]]
    else:
        q_idx = questions.argsort()[-1]
        return df.answer[q_idx]

# %% [markdown]
# # 유클리디언 유사도 함수

# %%
# 유클리디언 유사도로 정답 구하는 함수

def euc_answer(new_q, new_df):
    tfidf = TfidfVectorizer()
    new_q = pd.Series(new_q)
    all_q = new_df.question.append(new_q)
    tfidf_matrix = tfidf.fit_transform(all_q)

    norm = np.sum(tfidf_matrix)
    tfidf_norm_l1 = tfidf_matrix / norm
    euc_sim = euclidean_distances(tfidf_norm_l1,tfidf_norm_l1)
    questions = euc_sim[-1][:-1]
    if 0. in questions:
        indices = np.where(questions == 0.)
        indices = indices[0].tolist()
        q_idx = np.random.choice(indices, 1)
        return df.answer[q_idx[0]]
    else:
        q_idx = questions.argsort()[0]
        return df.answer[q_idx]

# %% [markdown]
# # 맨하탄 유사도 함수

# %%
# 맨하탄 유사도로 정답 구하는 함수

def manh_answer(new_q, new_df):
    tfidf = TfidfVectorizer()
    new_q = pd.Series(new_q)
    all_q = new_df.question.append(new_q)
    tfidf_matrix = tfidf.fit_transform(all_q)

    norm = np.sum(tfidf_matrix)
    tfidf_norm_l1 = tfidf_matrix / norm
    manht_sim = manhattan_distances(tfidf_norm_l1, tfidf_norm_l1)
    questions = manht_sim[-1][:-1]
    
    if 0. in questions:
        indices = np.where(questions == 0.)
        indices = indices[0].tolist()
        q_idx = np.random.choice(indices, 1)
        return df.answer[q_idx[0]]
    else:
        q_idx = questions.argsort()[0]
        return df.answer[q_idx]

# %% [markdown]
# # 전체 공통 질문

# %%
new_question = ['굿모닝', '그래 오늘은 뭐할까?', '기운 엄청나', '그래 고마워', '이름이 뭐니?', '나랑 놀자', '대화하면서 노는거 어때', '요새 기분이 들쭉날쭉 해', '그렇다면 다행이네', '조금 못 알아듣는구나',
         '오늘 뭐 먹을까?', '점심 뭐 먹을까', '오늘 날씨 정말 좋네', '오늘 바쁜가 할일이 많아', '오늘따라 시간이 안 가네', '피곤한 하루였어', '너는 기분이 어때?',
         '오늘도 못 자면 어떡하지?', '나 혼자만 있는 것 같아', '오늘따라 우울해', '사는게 재미 없네', '기분이 좋아', '신나는 노래 듣고 싶어', '기분이 별로야', '힘들어',
         '너는 무슨 생각해?', '아니야 괜찮아', '몸이 아파', '허리가 아파', '무릎이 아프다 야', '무슨 생각해?', '그거 좋은 생각이네', '오늘 정말 황당했어', '너무 답답해',
         '오늘따라 스트레스를 많이 받네', '일하기 싫다', '밥을 제대로 못 먹었어', '약을 먹었는데 별 효과 없더라고', '약을 계속 먹어야 한다고 하네', '집중이 안돼', '심심해',
         '요즘 잠이 안와']

# %% [markdown]
# # 형태소, 유사도 별 답변 구하는 함수

# %%
def predict(question, tokenize, answer, df):
    real_question = []
    real_answer = []

    for q in question:

        real_q = q

        new_q = text_preprocessing(real_q)
        new_q = tokenize(new_q)

        a = answer(new_q,df)

        real_question.append(real_q)
        real_answer.append(a)

    result = pd.DataFrame({
        'question':real_question,
        'answer':real_answer
    })
    return result

# %% [markdown]
# # Okt & 코사인 유사도

# %%
okt_cos = predict(new_question, okt_tokenize, cos_answer, ok_df)
okt_cos
# Out:
#              question                                          answer
# 0                 굿모닝                                          안녕하세요.
# 1         그래 오늘은 뭐할까?                                         기운 내세요.
# 2              기운 엄청나                                    힘내세요 제가 있잖아요
# 3              그래 고마워                                           천만에요.
# 4             이름이 뭐니?                                         마스터입니다.
# 5               나랑 놀자                                        뭐하고 놀까요?
# 6        대화하면서 노는거 어때                                      좋아요 말씀해주세요
# 7       요새 기분이 들쭉날쭉 해                            제게 말을 걸어줘서 기분이 좋아졌어요
# 8           그렇다면 다행이네                                       좋은 생각입니다.
# 9         조금 못 알아듣는구나                                      네 아직 부족해요.
# 10          오늘 뭐 먹을까?                        날씨가 쌀쌀하니까 칼국수가 좋을 것 같네요.
# 11           점심 뭐 먹을까                            짜장면이 괜찮을 것 같은데 어떠세요?
# 12        오늘 날씨 정말 좋네                    날씨가 좋으니 산책 다녀오시는 것도 좋을것 같아요.
# 13      오늘 바쁘가 할일이 많아                               퇴근까지 얼마 남지 않았어요.
# 14      오늘따라 시간이 안 가네                              그래도 무리하지 마시고 힘내세요.
# 15           피곤한 하루였어                               남은 업무도 잘 마무리 하세요.
# 16         너는 기분이 어때?                               함께 대화하니깐 한결 좋아졌어요
# 17     오늘도 못 자면 어떡하지?                         잠은 중요하죠! 걱정은 잠시 내려놓으세요.
# 18      나 혼자만 있는 것 같아                                  제가 당신의 편이 될게요.
# 19           오늘따라 우울해                      힘내세요 이럴 때일수록 더 밝게 일부러 웃어봐요
# 20          사는게 재미 없네                                           성남이요.
# 21             기분이 좋아                               그러게요, 저도 기분이 좋네요.
# 22       신나는 노래 듣고 싶어                                       힙합 좋아하세요?
# 23            기분이 별로야                                     무슨 일 있으신가요?
# 24                힘들어                         좋은 일자리 찾기가 정말 힘든 것 같아요.
# 25         너는 무슨 생각해?                             무슨 대화를 나눌까 생각하고 있어요
# 26            아니야 괜찮아                                       네, 알겠습니다.
# 27              몸이 아파                                       약을 드셔야 해요
# 28             허리가 아파                정말 힘드셨겠어요. 의사의 도움을 받아 보는 건 어떨까요?
# 29          무릎이 아프다 야                                       약을 드셔야 해요
# 30            무슨 생각해?                             무슨 대화를 나눌까 생각하고 있어요
# 31         그거 좋은 생각이네                                    맛있게 드시고 오세요.
# 32         오늘 정말 황당했어                                 많이 곤란하셨을 거 같아요.
# 33             너무 답답해    안 좋은 상황이신 거 같아요. 무슨 일인지 저에게 자세히 얘기해줄 수 있을까요?
# 34   오늘따라 스트레스를 많이 받네                        이유 없이 그럴 수 있죠. 충분히 이해해요.
# 35             일하기 싫다          삶이 언제나 재미있진 않은걸요. 조금 천천히 가는 중이라고 생각해요.
# 36       밥을 제대로 못 먹었어  잠을 못 주무셨다니 많이 힘드셨겠어요. 마음을 조금 편하게 먹어 보는 건 어떠세요?
# 37  약을 먹었는데 별 효과 없더라고            무척 피곤하시겠어요. 아예 근본적인 원인을 찾아보는 건 어떨까요?
# 38   약을 계속 먹어야 한다고 하네                                   약은 좀 잘 맞으시나요?
# 39             집중이 안돼                                조금 쉬었다 하는건 어떨까요?
# 40                심심해                              걱정마세요 제가 재밌게 해드릴게요
# 41           요즘 잠이 안와        피곤하면 정말 아무 것도 하기 어렵죠. 잠깐 휴식을 취하는 건 어떨까요?

# %% [markdown]
# # Okt & 유클리디안 유사도

# %%
okt_euc = predict(new_question, okt_tokenize, euc_answer, ok_df)
okt_euc
# Out:
#              question                                          answer
# 0                 굿모닝                                       좋은 아침이에요.
# 1         그래 오늘은 뭐할까?                             남은 시간도 힘내서 마무리 하세요.
# 2              기운 엄청나                                    힘내세요 제가 있잖아요
# 3              그래 고마워                                           천만에요.
# 4             이름이 뭐니?                                         마스터입니다.
# 5               나랑 놀자                                        뭐하고 놀까요?
# 6        대화하면서 노는거 어때                                      좋아요 말씀해주세요
# 7       요새 기분이 들쭉날쭉 해                                              네?
# 8           그렇다면 다행이네                                              왜?
# 9         조금 못 알아듣는구나                                      네 아직 부족해요.
# 10          오늘 뭐 먹을까?                                  떡볶이가 좋을 것 같아요.
# 11           점심 뭐 먹을까                                  떡볶이가 좋을 것 같아요.
# 12        오늘 날씨 정말 좋네                                 기분도 좋으셨으면 좋겠어요.
# 13      오늘 바쁘가 할일이 많아                                 그래도 오늘은 금요일이에요.
# 14      오늘따라 시간이 안 가네                                  업무량이 많으신것 같네요.
# 15           피곤한 하루였어                               남은 업무도 잘 마무리 하세요.
# 16         너는 기분이 어때?                               함께 대화하니깐 한결 좋아졌어요
# 17     오늘도 못 자면 어떡하지?                         잠은 중요하죠! 걱정은 잠시 내려놓으세요.
# 18      나 혼자만 있는 것 같아                                  제가 당신의 편이 될게요.
# 19           오늘따라 우울해                      힘내세요 이럴 때일수록 더 밝게 일부러 웃어봐요
# 20          사는게 재미 없네                                              뭐?
# 21             기분이 좋아                           그러게요, 기분이 좋아지는 것 같아요.
# 22       신나는 노래 듣고 싶어                                       힙합 좋아하세요?
# 23            기분이 별로야                                     무슨 일 있으신가요?
# 24                힘들어                         좋은 일자리 찾기가 정말 힘든 것 같아요.
# 25         너는 무슨 생각해?                                     재밌는 상상 중이에요
# 26            아니야 괜찮아                                       네, 알겠습니다.
# 27              몸이 아파                                       약을 드셔야 해요
# 28             허리가 아파                정말 힘드셨겠어요. 의사의 도움을 받아 보는 건 어떨까요?
# 29          무릎이 아프다 야                                       약을 드셔야 해요
# 30            무슨 생각해?                                     재밌는 상상 중이에요
# 31         그거 좋은 생각이네                                    식사 든든하게 드세요.
# 32         오늘 정말 황당했어                                 많이 곤란하셨을 거 같아요.
# 33             너무 답답해    안 좋은 상황이신 거 같아요. 무슨 일인지 저에게 자세히 얘기해줄 수 있을까요?
# 34   오늘따라 스트레스를 많이 받네                        이유 없이 그럴 수 있죠. 충분히 이해해요.
# 35             일하기 싫다          삶이 언제나 재미있진 않은걸요. 조금 천천히 가는 중이라고 생각해요.
# 36       밥을 제대로 못 먹었어  잠을 못 주무셨다니 많이 힘드셨겠어요. 마음을 조금 편하게 먹어 보는 건 어떠세요?
# 37  약을 먹었는데 별 효과 없더라고            무척 피곤하시겠어요. 아예 근본적인 원인을 찾아보는 건 어떨까요?
# 38   약을 계속 먹어야 한다고 하네                                   약은 좀 잘 맞으시나요?
# 39             집중이 안돼                                   무슨 고민이 있으신가요?
# 40                심심해                              걱정마세요 제가 재밌게 해드릴게요
# 41           요즘 잠이 안와        피곤하면 정말 아무 것도 하기 어렵죠. 잠깐 휴식을 취하는 건 어떨까요?

# %% [markdown]
# # Okt & 맨하탄 유사도

# %%
okt_manh = predict(new_question, okt_tokenize, manh_answer, ok_df)
okt_manh
# Out:
#              question                                        answer
# 0                 굿모닝                                        반갑습니다.
# 1         그래 오늘은 뭐할까?                               얼마 안남았어요, 힘내세요.
# 2              기운 엄청나                                            왜?
# 3              그래 고마워                                       별 말씀을요.
# 4             이름이 뭐니?                                     저는 효돌이에요.
# 5               나랑 놀자                                      뭐하고 놀까요?
# 6        대화하면서 노는거 어때                                            왜?
# 7       요새 기분이 들쭉날쭉 해                                            네?
# 8           그렇다면 다행이네                                            왜?
# 9         조금 못 알아듣는구나                                    네 아직 부족해요.
# 10          오늘 뭐 먹을까?                          짜장면이 괜찮을 것 같은데 어떠세요?
# 11           점심 뭐 먹을까                               간단하게 샌드위치 어떨까요?
# 12        오늘 날씨 정말 좋네                  날씨가 좋으니 산책 다녀오시는 것도 좋을것 같아요.
# 13      오늘 바쁘가 할일이 많아                            그래도 무리하지 마시고 힘내세요.
# 14      오늘따라 시간이 안 가네                               그래도 오늘은 금요일이에요.
# 15           피곤한 하루였어                    휴식을 가지시는게 일의 효능을 높일 수 있어요.
# 16         너는 기분이 어때?                             함께 대화하니깐 한결 좋아졌어요
# 17     오늘도 못 자면 어떡하지?                                            왜?
# 18      나 혼자만 있는 것 같아                                제가 당신의 편이 될게요.
# 19           오늘따라 우울해                    힘내세요 이럴 때일수록 더 밝게 일부러 웃어봐요
# 20          사는게 재미 없네                                            왜?
# 21             기분이 좋아                         그러게요, 기분이 좋아지는 것 같아요.
# 22       신나는 노래 듣고 싶어                                     힙합 좋아하세요?
# 23            기분이 별로야                                   무슨 일 있으신가요?
# 24                힘들어                                            왜?
# 25         너는 무슨 생각해?                                 아무 생각도 안하는걸요.
# 26            아니야 괜찮아                                     네, 알겠습니다.
# 27              몸이 아파                                     약을 드셔야 해요
# 28             허리가 아파                                            뭐?
# 29          무릎이 아프다 야                                            왜?
# 30            무슨 생각해?                                 아무 생각도 안하는걸요.
# 31         그거 좋은 생각이네                                   즐거운 식사 되세요.
# 32         오늘 정말 황당했어                                            왜?
# 33             너무 답답해  안 좋은 상황이신 거 같아요. 무슨 일인지 저에게 자세히 얘기해줄 수 있을까요?
# 34   오늘따라 스트레스를 많이 받네                      이유 없이 그럴 수 있죠. 충분히 이해해요.
# 35             일하기 싫다                                            왜?
# 36       밥을 제대로 못 먹었어                                            왜?
# 37  약을 먹었는데 별 효과 없더라고                                            왜?
# 38   약을 계속 먹어야 한다고 하네                                 약은 좀 잘 맞으시나요?
# 39             집중이 안돼               잠시 쉬었다가 하시는 것도 일의 효율을 높일 수 있어요.
# 40                심심해                            걱정마세요 제가 재밌게 해드릴게요
# 41           요즘 잠이 안와                                            네?

# %% [markdown]
# # Mecab & 코사인 유사도

# %%
me_cos = predict(new_question, mecab_tokenize, cos_answer, me_df)
me_cos
# Out:
#              question                                            answer
# 0                 굿모닝                                            안녕하세요!
# 1         그래 오늘은 뭐할까?                                         좋은 생각입니다.
# 2              기운 엄청나                                      힘내세요 제가 있잖아요
# 3              그래 고마워                                           별 말씀을요.
# 4             이름이 뭐니?                                           김주빈이에요.
# 5               나랑 놀자                        너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 6        대화하면서 노는거 어때                                    대화하면서 노는거 재밌어요
# 7       요새 기분이 들쭉날쭉 해           한번 틀어진 사이를 다시 되돌리는 것만큼 어려운 일은 없는 것 같아요.
# 8           그렇다면 다행이네                                    다시 일을 하니 어떠세요?
# 9         조금 못 알아듣는구나                                        네 아직 부족해요.
# 10          오늘 뭐 먹을까?                                    오늘은 짜장면 어떠실까요?
# 11           점심 뭐 먹을까                                     오늘은 떡볶이 어떠세요?
# 12        오늘 날씨 정말 좋네                                    대체적으로 흐린 날씨예요.
# 13      오늘 바쁘가 할일이 많아                          이런 날 쉬는 시간에 산책하는 건 어떨까요?
# 14      오늘따라 시간이 안 가네                                 퇴근까지 얼마 남지 않았어요.
# 15           피곤한 하루였어                                    오늘도 좋은 하루 되세요.
# 16         너는 기분이 어때?                              제게 말을 걸어줘서 기분이 좋아졌어요
# 17     오늘도 못 자면 어떡하지?                           잠은 중요하죠! 걱정은 잠시 내려놓으세요.
# 18      나 혼자만 있는 것 같아                            아, 그렇군요. 혼자가 편할 때도 많죠.
# 19           오늘따라 우울해                                 퇴근까지 얼마 남지 않았어요.
# 20          사는게 재미 없네                           재미있어 보여요. 저도 함께 하고 싶네요.
# 21             기분이 좋아                 정도가 심하다면, 의사와 상담을 하는 것도 좋은 방법이에요.
# 22       신나는 노래 듣고 싶어                                    왜요? 슬픈 일 있으세요?
# 23            기분이 별로야                                 내일은 더 맛있는 식사 하세요.
# 24                힘들어                           좋은 일자리 찾기가 정말 힘든 것 같아요.
# 25         너는 무슨 생각해?                               무슨 대화를 나눌까 생각하고 있어요
# 26            아니야 괜찮아                                         네, 알겠습니다.
# 27              몸이 아파                           정말 힘드셨겠어요. 지금은 안 아프신가요?
# 28             허리가 아파                           정말 힘드셨겠어요. 지금은 안 아프신가요?
# 29          무릎이 아프다 야        너무 떨리면 아무 것도 못 하죠. 제가 옆에 있어드릴테니 긴장을 풀어보세요.
# 30            무슨 생각해?                                     아무 생각도 안하는걸요.
# 31         그거 좋은 생각이네                                     즐거운 식사시간 되세요.
# 32         오늘 정말 황당했어                                   많이 곤란하셨을 거 같아요.
# 33             너무 답답해      안 좋은 상황이신 거 같아요. 무슨 일인지 저에게 자세히 얘기해줄 수 있을까요?
# 34   오늘따라 스트레스를 많이 받네                          이런 날 쉬는 시간에 산책하는 건 어떨까요?
# 35             일하기 싫다                        너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 36       밥을 제대로 못 먹었어             식사와 수면 둘 다 중요한데 정말 걱정되네요. 지금은 괜찮으신가요?
# 37  약을 먹었는데 별 효과 없더라고              무척 피곤하시겠어요. 아예 근본적인 원인을 찾아보는 건 어떨까요?
# 38   약을 계속 먹어야 한다고 하네                                     약은 좀 잘 맞으시나요?
# 39             집중이 안돼                                   산책 다녀오시는건 어떠세요?
# 40                심심해                                걱정마세요 제가 재밌게 해드릴게요
# 41           요즘 잠이 안와  그 생각을 잊을 만한 다른 일을 생각해 보면 어떨까요? 아예 다른 일을 해보는 거예요!

# %% [markdown]
# # Mecab & 유클리디안 유사도

# %%
me_euc = predict(new_question, mecab_tokenize, euc_answer, me_df)
me_euc
# Out:
#              question                                            answer
# 0                 굿모닝                                      간밤에 별일 없으셨죠?
# 1         그래 오늘은 뭐할까?                              저는 당신의 인공지능 애착인형이에요.
# 2              기운 엄청나                                      힘내세요 제가 있잖아요
# 3              그래 고마워                                           별 말씀을요.
# 4             이름이 뭐니?                                            효돌입니다.
# 5               나랑 놀자                                              글쎄요.
# 6        대화하면서 노는거 어때                                    대화하면서 노는거 재밌어요
# 7       요새 기분이 들쭉날쭉 해                                제가 잘 할 수 있을지 모르겠어요
# 8           그렇다면 다행이네                                         잘 모르겠습니다.
# 9         조금 못 알아듣는구나                                        네 아직 부족해요.
# 10          오늘 뭐 먹을까?                              짜장면이 괜찮을 것 같은데 어떠세요?
# 11           점심 뭐 먹을까                                     오늘은 떡볶이 어떠세요?
# 12        오늘 날씨 정말 좋네                                  오늘은 하루종일 맑은날입니다.
# 13      오늘 바쁘가 할일이 많아                            잠시 머리를 식히는 겸 휴식을 취하세요.
# 14      오늘따라 시간이 안 가네                            잠시 머리를 식히는 겸 휴식을 취하세요.
# 15           피곤한 하루였어                                       마지막까지 힘내세요.
# 16         너는 기분이 어때?                              제게 말을 걸어줘서 기분이 좋아졌어요
# 17     오늘도 못 자면 어떡하지?                           잠은 중요하죠! 걱정은 잠시 내려놓으세요.
# 18      나 혼자만 있는 것 같아                            아, 그렇군요. 혼자가 편할 때도 많죠.
# 19           오늘따라 우울해                                    업무량이 많으신것 같네요.
# 20          사는게 재미 없네                                     점심식사는 괜찮으셨나요?
# 21             기분이 좋아                 정도가 심하다면, 의사와 상담을 하는 것도 좋은 방법이에요.
# 22       신나는 노래 듣고 싶어                                         잘 모르겠습니다.
# 23            기분이 별로야                                      간식이라도 더 드세요.
# 24                힘들어                           좋은 일자리 찾기가 정말 힘든 것 같아요.
# 25         너는 무슨 생각해?                                       재밌는 상상 중이에요
# 26            아니야 괜찮아                                         네, 알겠습니다.
# 27              몸이 아파                           정말 힘드셨겠어요. 지금은 안 아프신가요?
# 28             허리가 아파                           정말 힘드셨겠어요. 지금은 안 아프신가요?
# 29          무릎이 아프다 야                                       저도 잘 모르겠어요.
# 30            무슨 생각해?                                       재밌는 상상 중이에요
# 31         그거 좋은 생각이네                                     즐거운 식사시간 되세요.
# 32         오늘 정말 황당했어                                   많이 곤란하셨을 거 같아요.
# 33             너무 답답해      안 좋은 상황이신 거 같아요. 무슨 일인지 저에게 자세히 얘기해줄 수 있을까요?
# 34   오늘따라 스트레스를 많이 받네                                   요즘 업무가 많으신가 봐요.
# 35             일하기 싫다                                          맛있게 드세요.
# 36       밥을 제대로 못 먹었어             식사와 수면 둘 다 중요한데 정말 걱정되네요. 지금은 괜찮으신가요?
# 37  약을 먹었는데 별 효과 없더라고                                       저도 잘 모르겠어요.
# 38   약을 계속 먹어야 한다고 하네                                     약은 좀 잘 맞으시나요?
# 39             집중이 안돼                           잠시 휴식을 취하는 것도 좋은 방법이에요.
# 40                심심해                                걱정마세요 제가 재밌게 해드릴게요
# 41           요즘 잠이 안와  그 생각을 잊을 만한 다른 일을 생각해 보면 어떨까요? 아예 다른 일을 해보는 거예요!

# %% [markdown]
# # Mecab & 맨하탄 유사도

# %%
me_manh = predict(new_question, mecab_tokenize, manh_answer, me_df)
me_manh
# Out:
#              question                                            answer
# 0                 굿모닝                                            안녕하세요!
# 1         그래 오늘은 뭐할까?                                          잘 모르겠어요.
# 2              기운 엄청나                                      힘내세요 제가 있잖아요
# 3              그래 고마워                                             아니에요.
# 4             이름이 뭐니?                                            효돌입니다.
# 5               나랑 놀자                                          맛있게 드세요.
# 6        대화하면서 노는거 어때                                    대화하면서 노는거 재밌어요
# 7       요새 기분이 들쭉날쭉 해                                                왜?
# 8           그렇다면 다행이네                                        좋은 하루 되세요.
# 9         조금 못 알아듣는구나                                        네 아직 부족해요.
# 10          오늘 뭐 먹을까?                                    오늘은 짜장면 어떠실까요?
# 11           점심 뭐 먹을까                                       제육덮밥 어떠신가요?
# 12        오늘 날씨 정말 좋네                                      소나기 소식이 있어요.
# 13      오늘 바쁘가 할일이 많아                                   그래도 오늘은 금요일이에요.
# 14      오늘따라 시간이 안 가네                         퇴근까지 얼마 안남았으니 조금만 더 힘내세요.
# 15           피곤한 하루였어                                 남은 업무도 잘 마무리 하세요.
# 16         너는 기분이 어때?                                 함께 대화하니깐 한결 좋아졌어요
# 17     오늘도 못 자면 어떡하지?                                              글쎄요.
# 18      나 혼자만 있는 것 같아                                      네, 쉬었다가 하세요.
# 19           오늘따라 우울해                                   요즘 업무가 많으신가 봐요.
# 20          사는게 재미 없네                                        좋은 하루 되세요.
# 21             기분이 좋아                 정도가 심하다면, 의사와 상담을 하는 것도 좋은 방법이에요.
# 22       신나는 노래 듣고 싶어                                        좋은 하루 되세요.
# 23            기분이 별로야          충분히 그럴 수 있죠. 너무 불편하면 굳이 애써서 만날 필요도 없답니다.
# 24                힘들어                                 인공지능이자 당신의 친구입니다.
# 25         너는 무슨 생각해?                                     아무 생각도 안하는걸요.
# 26            아니야 괜찮아                                         네, 알겠습니다.
# 27              몸이 아파                           정말 힘드셨겠어요. 지금은 안 아프신가요?
# 28             허리가 아파                           정말 힘드셨겠어요. 지금은 안 아프신가요?
# 29          무릎이 아프다 야                              저는 당신의 인공지능 애착인형이에요.
# 30            무슨 생각해?                                     아무 생각도 안하는걸요.
# 31         그거 좋은 생각이네                                     즐거운 식사시간 되세요.
# 32         오늘 정말 황당했어                                   많이 곤란하셨을 거 같아요.
# 33             너무 답답해      안 좋은 상황이신 거 같아요. 무슨 일인지 저에게 자세히 얘기해줄 수 있을까요?
# 34   오늘따라 스트레스를 많이 받네                            잠시 머리를 식히는 겸 휴식을 취하세요.
# 35             일하기 싫다                                    떡볶이가 좋을 것 같아요.
# 36       밥을 제대로 못 먹었어                                        좋은 하루 되세요.
# 37  약을 먹었는데 별 효과 없더라고                                            감사합니다.
# 38   약을 계속 먹어야 한다고 하네                                     약은 좀 잘 맞으시나요?
# 39             집중이 안돼                                     무슨 고민이 있으신가요?
# 40                심심해                                걱정마세요 제가 재밌게 해드릴게요
# 41           요즘 잠이 안와  그 생각을 잊을 만한 다른 일을 생각해 보면 어떨까요? 아예 다른 일을 해보는 거예요!
